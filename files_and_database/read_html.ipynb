# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/files_and_database/read_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dfs = pd.read_html("https://www.rbcdirectinvesting.com/index-b.html")
len(dfs)
# Out:
# 3

# %%
dfs[0]
# Out:
#   Qualifying Net Contributions (CAD):  Avion points you will receive:  \
# 0                    $5,000 (minimum)                           15000
# 1                             $45,000                           35000
# 2                            $105,000                           65000
# 3                            $975,000                          500000
#
#                              Equivalent Value (CAD):
# 0       $350 (round-trip flight for a quick getaway)
# 1  $750 (round-trip flight to explore North America)
# 2         $1,300 (round-trip flight to visit Europe)
# 3    $10,000 (5 round-trip flights to see the world)

# %%
dfs[1]
# Out:
#                                  For RBC & RMFI Inc.  \
# 0  Tax Free Savings Account (TFSA)  Registered Re...
#
#                        For RBC Direct Investing Inc.
# 0  Tax Free Savings Account (TFSA)  Registered Re...

# %%
dfs[2]
# Out:
#   Qualifying Net Contributions (CAD):  Avion points you will receive:  \
# 0                    $5,000 (minimum)                           15000
# 1                             $45,000                           35000
# 2                            $105,000                           65000
# 3                            $975,000                          500000
#
#                                         Value (CAD):
# 0       $350 (round-trip flight for a quick getaway)
# 1  $750 (round-trip flight to explore North America)
# 2         $1,300 (round-trip flight to visit Europe)
# 3    $10,000 (5 round-trip flights to see the world)
