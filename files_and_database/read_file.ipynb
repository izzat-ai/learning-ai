# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/files_and_database/read_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - ushbu sahifada faqatgina csv va boshqa turdagi fayllardan ma'lumotlarni o'qish va faylga yozish o'rganiladi

# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93 (from 1)
# Receiving objects: 100% (145/145), 9.72 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# csv faylini o'qish
df = pd.read_csv("/content/praktikum_datasets/Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
# csv faylini o'qish
df2 = pd.read_csv("/content/praktikum_datasets/automobile_data.csv", index_col=0)
df2.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# excel faylini o'qish
df_excel = pd.read_excel("/content/praktikum_datasets/netflix.xlsx")
df_excel.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   rating             1000 non-null   object
#  2   ratingLevel        941 non-null    object
#  3   ratingDescription  1000 non-null   int64
#  4   release year       1000 non-null   int64
#  5   user rating score  605 non-null    float64
#  6   user rating size   1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df_excel2 = pd.read_excel("/content/praktikum_datasets/E-Commerce-Dataset.xlsx")
df_excel2.head()
# Out:
#    Unnamed: 0 Unnamed: 1            Unnamed: 2  \
# 0         NaN       Data              Variable
# 1         NaN     E Comm            CustomerID
# 2         NaN     E Comm                 Churn
# 3         NaN     E Comm                Tenure
# 4         NaN     E Comm  PreferredLoginDevice
#
#                            Unnamed: 3
# 0                         Discerption
# 1                  Unique customer ID
# 2                          Churn Flag
# 3  Tenure of customer in organization
# 4  Preferred login device of customer

# %%
df_excel2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  21 non-null     object
#  2   Unnamed: 2  21 non-null     object
#  3   Unnamed: 3  21 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 804.0+ bytes

# %% [markdown]
# **Faylga yozish**

# %%
df_1 = df.head()
df_1
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# csv faylga yozish
df_1.to_csv('df1.csv')

# %%
# df1.csv dan o'qish
pd.read_csv('df1.csv', index_col=0)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_2 = df2.head()
df_2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
# csv faylidagi ma'lumotlarni excel jadvalga yozish
df_2.to_excel('df2.xlsx')

# %%
# yuqoridagi excel jadvalni o'qish
pd.read_excel('df2.xlsx', index_col=0)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage  price
# index
# 0                 four         111               21  13495
# 1                 four         111               21  16500
# 2                  six         154               19  16500
# 3                 four         102               24  13950
# 4                 five         115               18  17450

# %%
# csv faylga ustun saqlash
df_col = df_excel['title']

# %%
df_col.to_csv('df_excel_column.csv')

# %%
# yuqoridagi jadvalni o'qish
pd.read_csv("df_excel_column.csv", index_col=0)
# Out:
#                        title
# 0               White Chicks
# 1        Lucky Number Slevin
# 2             Grey's Anatomy
# 3               Prison Break
# 4      How I Met Your Mother
# ..                       ...
# 995                  The BFG
# 996  The Secret Life of Pets
# 997         Precious Puppies
# 998              Beary Tales
# 999          Growing Up Wild
#
# [1000 rows x 1 columns]

# %% [markdown]
# - faylga saqlashda , indeksni bermaslik

# %%
df_3 = df_excel2['Unnamed: 2']
df_3
# Out:
# 0                        Variable
# 1                      CustomerID
# 2                           Churn
# 3                          Tenure
# 4            PreferredLoginDevice
# 5                        CityTier
# 6                 WarehouseToHome
# 7            PreferredPaymentMode
# 8                          Gender
# 9                  HourSpendOnApp
# 10       NumberOfDeviceRegistered
# 11               PreferedOrderCat
# 12              SatisfactionScore
# 13                  MaritalStatus
# 14                NumberOfAddress
# 15                       Complain
# 16    OrderAmountHikeFromlastYear
# 17                     CouponUsed
# 18                     OrderCount
# 19              DaySinceLastOrder
# 20                 CashbackAmount
# Name: Unnamed: 2, dtype: object

# %%
df_3.to_excel('df_3.xlsx', index=False)

# %%
# yuqoridagi jadvalni o'qish
pd.read_excel('df_3.xlsx')
# Out:
#                      Unnamed: 2
# 0                      Variable
# 1                    CustomerID
# 2                         Churn
# 3                        Tenure
# 4          PreferredLoginDevice
# 5                      CityTier
# 6               WarehouseToHome
# 7          PreferredPaymentMode
# 8                        Gender
# 9                HourSpendOnApp
# 10     NumberOfDeviceRegistered
# 11             PreferedOrderCat
# 12            SatisfactionScore
# 13                MaritalStatus
# 14              NumberOfAddress
# 15                     Complain
# 16  OrderAmountHikeFromlastYear
# 17                   CouponUsed
# 18                   OrderCount
# 19            DaySinceLastOrder
# 20               CashbackAmount

# %% [markdown]
# - faqatgina kerakli ustunlarni faylga yozish

# %%
df_excel2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df_excel2.to_csv('df_4.csv', index=False, columns=['Unnamed: 2', 'Unnamed: 3'])

# %%
# yuqoridagi jadvalni o'qish
pd.read_csv('df_4.csv')
# Out:
#                      Unnamed: 2  \
# 0                      Variable
# 1                    CustomerID
# 2                         Churn
# 3                        Tenure
# 4          PreferredLoginDevice
# 5                      CityTier
# 6               WarehouseToHome
# 7          PreferredPaymentMode
# 8                        Gender
# 9                HourSpendOnApp
# 10     NumberOfDeviceRegistered
# 11             PreferedOrderCat
# 12            SatisfactionScore
# 13                MaritalStatus
# 14              NumberOfAddress
# 15                     Complain
# 16  OrderAmountHikeFromlastYear
# 17                   CouponUsed
# 18                   OrderCount
# 19            DaySinceLastOrder
# 20               CashbackAmount
#
#                                            Unnamed: 3
# 0                                         Discerption
# 1                                  Unique customer ID
# 2                                          Churn Flag
# ...
