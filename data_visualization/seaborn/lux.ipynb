# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/data_visualization/seaborn/lux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install lux-api
import lux
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 23.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.5 MB/s eta 0:00:00
# ...
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185710 sha256=866568600293d990be5c97379c7bfe8e62123f18533242a1806738afe4c2400a
#   Stored in directory: /root/.cache/pip/wheels/c4/96/d2/ffa7f6c489166338d6d66a644375d56e6d794b780f1bb671ac
# ...
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540453 sha256=1e15b21c74e2bc81921b7b2c5b0e31cf825acd56f820308286117b905dcb2c37
# ...

# %%
np.random.seed(42)

df_sales = pd.DataFrame({
    "order_id": range(1, 301),
    "region": np.random.choice(["Tashkent", "Samarkand", "Bukhara"], 300),
    "category": np.random.choice(["Phone", "Laptop", "Accessories"], 300),
    "price": np.random.randint(100, 1500, 300),
    "quantity": np.random.randint(1, 5, 300),
    "customer_age": np.random.randint(18, 60, 300)
})

# %%
vrb = df_sales
vrb.exported
# Out:
# /tmp/ipython-input-1391488269.py:2: UserWarning:
# No widget attached to the dataframe.Please assign dataframe to an output variable.
# See more: https://lux-api.readthedocs.io/en/latest/source/guide/FAQ.html#troubleshooting-tips
# []

# %%
df_sales.intent = ['region', 'price']
df_sales.display_lux()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3633803903.py in <cell line: 0>()
#       1 df_sales.intent = ['region', 'price']
# ----> 2 df_sales.display_lux()
#
# /usr/local/lib/python3.12/dist-packages/lux/core/frame.py in __getattr__(self, name)
#     175     #####################
#     176     def __getattr__(self, name):
# --> 177         ret_value = super(LuxDataFrame, self).__getattr__(name)
#     178         self.expire_metadata()
#     179         self.expire_recs()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'LuxDataFrame' object has no attribute 'display_lux'

# %%
df_sales.exported
# Out:
# /tmp/ipython-input-2607503772.py:1: UserWarning:
# No widget attached to the dataframe.Please assign dataframe to an output variable.
# See more: https://lux-api.readthedocs.io/en/latest/source/guide/FAQ.html#troubleshooting-tips
# []
