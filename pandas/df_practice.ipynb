# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/df_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###N1
# **How can you create a DataFrame from a dictionary containing lists?**

# %%
lst = [1, 2, 3, 4, 5]
df = pd.DataFrame(lst, index=['a', 'b', 'c', 'd', 'e'])
print(df)
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %% [markdown]
# ###N2
# **What method is used to display the first 5 rows of a DataFrame?**

# %%
df.head()
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %% [markdown]
# ###N3
# **How can you access a single column from a DataFrame and what data type does it return?**

# %%
df[0]
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: 0, dtype: int64

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###N4
# **How do you check for missing values in a DataFrame?**

# %%
#df.isnull()
df.notnull()
# Out:
#       0
# a  True
# b  True
# c  True
# d  True
# e  True

# %% [markdown]
# ###N5
# **What is the difference between `df.loc[]` and `df.iloc[]`?**

# %%
# .loc[] works with the index name, while .iloc[] works with the index number
