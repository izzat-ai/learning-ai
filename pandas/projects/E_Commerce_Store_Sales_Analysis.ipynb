# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/projects/E_Commerce_Store_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Store sales data tables for one day
raw_data = {
    'Customer_ID': [101, 102, 103, 104, 105, 106],
    'Name': ['Anvar', 'Malika', None, 'Shaxzod', 'Zilola', 'Anvar'],
    'Product': ['Yengil Oyoq kiyim', 'Sumka', 'Telefon', 'Ko\'ylak', 'Sumka', 'Yengil Oyoq kiyim'],
    'Price': [45.0, np.nan, 800.0, 30.0, 65.0, 45.0],
    'Quantity': [2, 1, 1, 3, 2, 1],
    'Status': ['Yetkazildi', 'Bekor qilindi', 'Yetkazildi', 'Yetkazildi', 'Kutilmoqda', 'Yetkazildi']
}

df = pd.DataFrame(raw_data)
print(df)
# Out:
#    Customer_ID     Name            Product  Price  Quantity         Status
# 0          101    Anvar  Yengil Oyoq kiyim   45.0         2     Yetkazildi
# 1          102   Malika              Sumka    NaN         1  Bekor qilindi
# 2          103     None            Telefon  800.0         1     Yetkazildi
# 3          104  Shaxzod            Ko'ylak   30.0         3     Yetkazildi
# 4          105   Zilola              Sumka   65.0         2     Kutilmoqda
# 5          106    Anvar  Yengil Oyoq kiyim   45.0         1     Yetkazildi

# %%
df.head(3)
# Out:
#    Customer_ID    Name            Product  Price  Quantity         Status
# 0          101   Anvar  Yengil Oyoq kiyim   45.0         2     Yetkazildi
# 1          102  Malika              Sumka    NaN         1  Bekor qilindi
# 2          103    None            Telefon  800.0         1     Yetkazildi

# %%
df.shape
# Out:
# (6, 6)

# %%
# identify unnamed line
df[df['Name'].isna()]
# Out:
#    Customer_ID  Name  Product  Price  Quantity      Status
# 2          103  None  Telefon  800.0         1  Yetkazildi
