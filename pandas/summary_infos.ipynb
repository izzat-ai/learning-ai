# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/summary_infos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "Name": ["Ali", "Vali", "Hasan", "Olim", None],
    "Age": [25, 32, np.nan, 28, 40],
    "Salary": [3500.5, 4200.0, 5000.2, np.nan, 3100.8],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Join_Date": pd.to_datetime(["2021-01-10", "2020-07-15", None, "2022-03-01", "2019-11-11"])
})

# %%
df

# %%
# df ohiridan 2 ta qatorini ko'rish
df.tail(2)

# %%
# df haqida umumiy ma'lumotlarni ko'rish
df.info()

# %%
# faqatgina raqamli ustunlar ma'lumotlarini olish
df.describe()
