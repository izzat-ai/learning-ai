# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['Ali', 'Vali', 'Hasan', 'Olim', 'Dilnoza', 'Zafar', 'Nodira'],
    'Age': [25, 32, 28, 45, 22, 36, 29],
    'City': ['Toshkent', 'Samarqand', 'Buxoro', 'Toshkent', 'Andijon', 'Samarqand', 'Buxoro'],
    'Score': [88.5, 92.0, 75.5, 95.0, 81.0, 78.5, 90.5],
    'Salary': [5000000, 7200000, 4800000, 9500000, 4200000, 6500000, 6000000]
}
df = pd.DataFrame(data)
df

# %%
df.info()

# %%
df.head(3)

# %%
df.tail(2)

# %%
# DataFrame’dan faqat name va score ustunlarini ajratib olish
df[['Name', 'Score']]

# %%
# salary ustunini 1.1 ga ko‘paytirib, yangidan new_salary nomli ustun yaratish
df['New_Salary'] = df['Salary']*1.1
df

# %%
data2 = {
    "Uzbekistan": {"pop": 36, "area": 450, "capital": "Tashkent"},
    "Kazakhstan": {"pop": 20, "area": 2700, "capital": "Astana"},
    "Kyrgyzstan": {"pop": 7,  "area": 199, "capital": "Bishkek"}
}
df2 = pd.DataFrame(data2)
df2

# %%
# area bo'yicha eng katta davlatni aniqlash
df2.loc['area'].idxmax()

# %%
df2.reindex(['A', 'B', 'C', 'D', 'E', 'F', 'G'])
df2.reset_index()

# %%
df

# %%
df.index.is_unique

# %%
df.index.has_duplicates

# %%
df2.index.has_duplicates

# %%
df2.sort_index()

# %%
df.reindex(['A', 'B', 'C', 'D', 'E', 'F', 'G'], fill_value=0)

# %%
df.drop(1)

# %%
df.drop('City', axis=1)

# %%
ser1 = pd.Series([10, 30, 20, 40, 50], index=['A', 'B', 'C', 'D', 'E'])
ser1

# %%
ser1[['C', 'D']]

# %%
ser1[ser1>25]

# %%
df

# %%
df[df['City'] == 'Toshkent']

# %%
df.loc[3]

# %%
df.at[3, 'Age'] = 11
df

# %%
df.iat[2, 2]

# %%
df['Score']+5

# %%
df['Salary'].apply(lambda x: str(x)+" mln")

# %%
df['City'].map({'Toshkent':"Tashkent", 'Samarqand':"Samarkand"})

# %%
df

# %%
df.sort_values(by='Age')

# %%
df.sort_values(by='Score', ascending=False)

# %%
df['new_score'] = df['Score'].rank().sort_values(ascending=False)
df

# %%
df['Salary'].agg(['min', 'max', 'mean', 'sum'])

# %%
df['Score'].agg(['median', 'std'])

# %%
df.describe()

# %%
df[['Age', 'Score', 'Salary']].corr()

# %%
df_numeric = df.select_dtypes(include='number')
df_numeric.corr()
