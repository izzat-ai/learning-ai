# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/practice/practice_all02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Age': [25, 30, 35, 28],
    'City': ['Tashkent', 'Samarkand', 'Bukhara', 'Fergana']
}

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#      Name  Age       City
# 0     Ali   25   Tashkent
# 1    Vali   30  Samarkand
# 2  Sardor   35    Bukhara
# 3   Jasur   28    Fergana

# %%
students = [
    ['Ahmad', 85, 'Math'],
    ['Bekzod', 92, 'Physics'],
    ['Dilshod', 78, 'Chemistry'],
    ['Eldor', 88, 'Biology']
]
df2 = pd.DataFrame(students, columns=['Student', 'Score', 'Subject'])
df2
# Out:
#    Student  Score    Subject
# 0    Ahmad     85       Math
# 1   Bekzod     92    Physics
# 2  Dilshod     78  Chemistry
# 3    Eldor     88    Biology

# %%
df3 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800],
    'Stock': [50, 120, 80, 200, 45],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Electronics']
})

# only Product and Price columns
df3[['Product', 'Price']]
# Out:
#   Product  Price
# 0  Laptop   1000
# 1   Phone    500
# 2  Tablet    300
# 3   Watch    200
# 4  Camera    800

# %%
df4 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Math': [85, 90, 78, 92, 88],
    'Physics': [88, 85, 90, 87, 91],
    'Chemistry': [90, 88, 85, 89, 86],
    'Biology': [87, 91, 88, 90, 89]
})
df4
# Out:
#       Name  Math  Physics  Chemistry  Biology
# 0    Alice    85       88         90       87
# 1      Bob    90       85         88       91
# 2  Charlie    78       90         85       88
# 3    David    92       87         89       90
# 4      Eve    88       91         86       89

# %%
# Select columns 2 and 4 by number
df4.iloc[:, [1, 3]]
# Out:
#    Math  Chemistry
# 0    85         90
# 1    90         88
# 2    78         85
# 3    92         89
# 4    88         86

# %%
# Create a DataFrame from this nested dictionary
products = {
    'electronics': {
        'laptop': 1200,
        'phone': 800,
        'tablet': 500
    },
    'furniture': {
        'chair': 150,
        'table': 300,
        'sofa': 800
    }
}
df5 = pd.DataFrame(products)
df5
# Out:
#         electronics  furniture
# laptop       1200.0        NaN
# phone         800.0        NaN
# tablet        500.0        NaN
# chair           NaN      150.0
# table           NaN      300.0
# sofa            NaN      800.0

# %%
# Create a DataFrame from this data and display the row and column names
company_data = {
    'IT': {
        'employees': 50,
        'budget': 500000,
        'projects': 12
    },
    'HR': {
        'employees': 15,
        'budget': 100000,
        'projects': 3
    },
    'Sales': {
        'employees': 30,
        'budget': 200000,
        'projects': 8
    }
}
df6 = pd.DataFrame(company_data)
df6
# Out:
#                IT      HR   Sales
# employees      50      15      30
# budget     500000  100000  200000
# projects       12       3       8

# %%
df7 = pd.DataFrame({
    'ID': [101, 102, 103, 104, 105],
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Salary': [5000, 6000, 5500, 7000, 6500]
})
df7
# Out:
#     ID    Name  Salary
# 0  101     Ali    5000
# 1  102    Vali    6000
# 2  103  Sardor    5500
# 3  104   Jasur    7000
# 4  105   Kamol    6500

# %%
# Set the 'ID' column as index
df7.set_index('ID', inplace=True)

# %%
df7
# Out:
#        Name  Salary
# ID
# 101     Ali    5000
# 102    Vali    6000
# 103  Sardor    5500
# 104   Jasur    7000
# 105   Kamol    6500

# %%
df8 = pd.DataFrame({
    'Name': ['Product_A', 'Product_B', 'Product_C', 'Product_D'],
    'Price': [100, 200, 150, 300],
    'Stock': [50, 30, 45, 20]
})
df8
# Out:
#         Name  Price  Stock
# 0  Product_A    100     50
# 1  Product_B    200     30
# 2  Product_C    150     45
# 3  Product_D    300     20

# %%
# Change the indices to ['P1', 'P2', 'P3', 'P4']
df8.index = ['P1', 'P2', 'P3', 'P4']
df8
# Out:
#          Name  Price  Stock
# P1  Product_A    100     50
# P2  Product_B    200     30
# P3  Product_C    150     45
# P4  Product_D    300     20

# %%
df9 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Age': [25, 30, 35, 28, 32],
    'Salary': [5000, 6000, 5500, 7000, 6500]
}, index=[101, 102, 103, 104, 105])
df9
# Out:
#        Name  Age  Salary
# 101     Ali   25    5000
# 102    Vali   30    6000
# 103  Sardor   35    5500
# 104   Jasur   28    7000
# 105   Kamol   32    6500

# %%
# Output the row with index 103
df9.loc[103]
# Out:
# Name      Sardor
# Age           35
# Salary      5500
# Name: 103, dtype: object

# %%
df10 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800],
    'Stock': [50, 120, 80, 200, 45]
}, index=['A', 'B', 'C', 'D', 'E'])
df10
# Out:
#   Product  Price  Stock
# A  Laptop   1000     50
# B   Phone    500    120
# C  Tablet    300     80
# D   Watch    200    200
# E  Camera    800     45

# %%
# Extract rows 'B' to 'D'
df10.loc['B':'D']
# Out:
#   Product  Price  Stock
# B   Phone    500    120
# C  Tablet    300     80
# D   Watch    200    200

# %%
df11 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Age': [25, 30, 35, 28, 32],
    'Salary': [5000, 6000, 5500, 7000, 6500]
})
df11
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500
# 3   Jasur   28    7000
# 4   Kamol   32    6500

# %%
# Find employees over 30 years old
df11[df11['Age'] > 30]
# Out:
#      Name  Age  Salary
# 2  Sardor   35    5500
# 4   Kamol   32    6500

# %%
df12 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800],
    'Stock': [50, 120, 80, 200, 45],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Electronics']
})
df12
# Out:
#   Product  Price  Stock     Category
# 0  Laptop   1000     50  Electronics
# 1   Phone    500    120  Electronics
# 2  Tablet    300     80  Electronics
# 3   Watch    200    200  Accessories
# 4  Camera    800     45  Electronics

# %%
# Find products in the Electronics category priced over 500
df12[(df12['Price']>500) & (df12['Category']=='Electronics')]
# Out:
#   Product  Price  Stock     Category
# 0  Laptop   1000     50  Electronics
# 4  Camera    800     45  Electronics

# %%
df13 = pd.DataFrame({
    'Name': ['Laptop', 'Phone', 'Tablet'],
    'Price': [1000, 500, 300],
    'Stock': [50, 120, 80]
})
df13
# Out:
#      Name  Price  Stock
# 0  Laptop   1000     50
# 1   Phone    500    120
# 2  Tablet    300     80

# %%
# Sort by Price in descending order
df13.sort_values(by='Price', ascending=False)
# Out:
#      Name  Price  Stock
# 0  Laptop   1000     50
# 1   Phone    500    120
# 2  Tablet    300     80

# %%
df14 = pd.DataFrame({
    'Student': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Math': [85, 90, 85, 92, 85],
    'Physics': [88, 85, 90, 87, 91]
})
df14
# Out:
#   Student  Math  Physics
# 0     Ali    85       88
# 1    Vali    90       85
# 2  Sardor    85       90
# 3   Jasur    92       87
# 4   Kamol    85       91

# %%
# Sort in ascending order first by 'Math', then by 'Physics'
df14.sort_values(by=['Math', 'Physics'])
# Out:
#   Student  Math  Physics
# 0     Ali    85       88
# 2  Sardor    85       90
# 4   Kamol    85       91
# 1    Vali    90       85
# 3   Jasur    92       87

# %%
data2 = {
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
}
df15 = pd.DataFrame(data2)
df15
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
# Multiply the values ​​in column A by 2
df15*2
# Out:
#     A    B     C
# 0   2   20   200
# 1   4   40   400
# 2   6   60   600
# 3   8   80   800
# 4  10  100  1000

# %%
df16 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor'],
    'Age': [25, 30, 35],
    'Salary': [5000, 6000, 5500]
})
df16
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500

# %%
# Create the general information in each row as a string: "Ali, 25 years old, salary 5000
df16.apply(lambda row: f"{row['Name']}, {row['Age']}, {row['Salary']}", axis=1)
# Out:
# 0       Ali, 25, 5000
# 1      Vali, 30, 6000
# 2    Sardor, 35, 5500
# dtype: object

# %%
df17 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Department': ['IT', 'HR', 'IT', 'Sales'],
    'Salary': [5000, 4000, 5500, 4500]
})
df17
# Out:
#      Name Department  Salary
# 0     Ali         IT    5000
# 1    Vali         HR    4000
# 2  Sardor         IT    5500
# 3   Jasur      Sales    4500

# %%
# Group by Department and calculate the average salary in each department
df17.groupby('Department')['Salary'].mean()
# Out:
# Department
# HR       4000.0
# IT       5250.0
# Sales    4500.0
# Name: Salary, dtype: float64

# %%
df18 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Laptop', 'Tablet', 'Phone', 'Laptop'],
    'Store': ['A', 'A', 'B', 'A', 'B', 'A'],
    'Sales': [5, 8, 3, 6, 9, 4]
})
df18
# Out:
#   Product Store  Sales
# 0  Laptop     A      5
# 1   Phone     A      8
# 2  Laptop     B      3
# 3  Tablet     A      6
# 4   Phone     B      9
# 5  Laptop     A      4

# %%
# Group by 'Product' and 'Store' and calculate total sales
df18.groupby(by=['Product', 'Store'])['Sales'].sum()
# Out:
# Product  Store
# Laptop   A        9
#          B        3
# Phone    A        8
#          B        9
# Tablet   A        6
# Name: Sales, dtype: int64

# %%
df19 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor'],
    'Math': [85, 90, 78],
    'Physics': [88, 85, 90]
})
df19
# Out:
#      Name  Math  Physics
# 0     Ali    85       88
# 1    Vali    90       85
# 2  Sardor    78       90

# %%
# In the 3rd row, output the score of 'Math' and 'Physics'
df19.iloc[[2], [1, 2]]
# Out:
#    Math  Physics
# 2    78       90

# %%
df20 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch'],
    'Price': [1000, 500, 300, 200],
    'Stock': [50, 120, 80, 200]
}, index=['A', 'B', 'C', 'D'])
df20
# Out:
#   Product  Price  Stock
# A  Laptop   1000     50
# B   Phone    500    120
# C  Tablet    300     80
# D   Watch    200    200

# %%
# Change the value of 'Price' in row C to 350
df20.iat[2, 1] = 350

# %%
df20
# Out:
#   Product  Price  Stock
# A  Laptop   1000     50
# B   Phone    500    120
# C  Tablet    350     80
# D   Watch    200    200

# %%
df21 = pd.DataFrame({
    'A': [10, 20, 30],
    'B': [5, 15, 25],
    'C': [3, 7, 9]
})
df21
# Out:
#     A   B  C
# 0  10   5  3
# 1  20  15  7
# 2  30  25  9

# %%
# Calculate the sum of the values ​​in each row
df21.sum(axis=1)
# Out:
# 0    18
# 1    42
# 2    64
# dtype: int64

# %%
df22 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet'],
    'Price': [1000, 500, 300],
    'Discount': [100, 50, 30]
})
df22
# Out:
#   Product  Price  Discount
# 0  Laptop   1000       100
# 1   Phone    500        50
# 2  Tablet    300        30

# %%
# Calculate the price of each product after discount
df22['price2'] = df22['Price'] - df22['Discount']
df22
# Out:
#   Product  Price  Discount  price2
# 0  Laptop   1000       100     900
# 1   Phone    500        50     450
# 2  Tablet    300        30     270

# %%
df23 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor'],
    'Age': [25, 30, 35]
})
df23
# Out:
#      Name  Age
# 0     Ali   25
# 1    Vali   30
# 2  Sardor   35

# %%
# Add a new column 'Salary' to the DataFrame: [5000, 6000, 5500
df23['Salary'] = [5000, 6000, 5500]
df23
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500

# %%
def age_category(age):
    if age < 25:
        return 'Young'
    elif age < 40:
        return 'Adult'
    else:
        return 'Senior'

df24 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Age': [22, 30, 45, 28]
})
df24
# Out:
#      Name  Age
# 0     Ali   22
# 1    Vali   30
# 2  Sardor   45
# 3   Jasur   28

# %%
# Create a 'Category' column based on the 'Age' column
df24['Category'] = df24.apply(lambda x: age_category(x['Age']), axis=1)
df24
# Out:
#      Name  Age Category
# 0     Ali   22    Young
# 1    Vali   30    Adult
# 2  Sardor   45   Senior
# 3   Jasur   28    Adult

# %%
df25 = pd.DataFrame({
    'Name': ['Sardor', 'Ali', 'Vali', 'Jasur'],
    'Age': [35, 25, 30, 28],
    'Salary': [5500, 5000, 6000, 7000]
})
df25
# Out:
#      Name  Age  Salary
# 0  Sardor   35    5500
# 1     Ali   25    5000
# 2    Vali   30    6000
# 3   Jasur   28    7000

# %%
# Sort alphabetically by Name
df25.sort_values(by='Name')
# Out:
#      Name  Age  Salary
# 1     Ali   25    5000
# 3   Jasur   28    7000
# 0  Sardor   35    5500
# 2    Vali   30    6000

# %%
df26 = pd.DataFrame({
    'Student': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Math': [85, 90, 78, 92],
    'Physics': [88, 85, 90, 87]
})
df26
# Out:
#   Student  Math  Physics
# 0     Ali    85       88
# 1    Vali    90       85
# 2  Sardor    78       90
# 3   Jasur    92       87

# %%
# Sort by Math' in descending order and extract the top 2 results
df26.sort_values(by='Math', ascending=False).head(2)
# Out:
#   Student  Math  Physics
# 3   Jasur    92       87
# 1    Vali    90       85

# %%
df27 = pd.DataFrame({
    'Student': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Score': [85, 92, 78, 95, 88]
})
df27
# Out:
#   Student  Score
# 0     Ali     85
# 1    Vali     92
# 2  Sardor     78
# 3   Jasur     95
# 4   Kamol     88

# %%
# Output each student's ranking
df27['Score'].rank()
# Out:
# 0    2.0
# 1    4.0
# 2    1.0
# 3    5.0
# 4    3.0
# Name: Score, dtype: float64

# %%
df28 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Sales': [150, 320, 200, 450, 180]
})
df28
# Out:
#   Product  Sales
# 0  Laptop    150
# 1   Phone    320
# 2  Tablet    200
# 3   Watch    450
# 4  Camera    180

# %%
# Find the top 3 products by sales
df28['Sales'].rank().sort_values()
# Out:
# 0    1.0
# 4    2.0
# 2    3.0
# 1    4.0
# 3    5.0
# Name: Sales, dtype: float64

# %% [markdown]
# - top 3 products: Tablet, Phone, Watch

# %%
df29 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800]
})
df29
# Out:
#   Product  Price
# 0  Laptop   1000
# 1   Phone    500
# 2  Tablet    300
# 3   Watch    200
# 4  Camera    800

# %%
# Output the total, minimum, maximum and average price of all products
df29.groupby('Product')['Price'].agg(['min', 'max', 'mean', 'sum'])
# Out:
#           min   max    mean   sum
# Product
# Camera    800   800   800.0   800
# Laptop   1000  1000  1000.0  1000
# Phone     500   500   500.0   500
# Tablet    300   300   300.0   300
# Watch     200   200   200.0   200

# %%
df30 = pd.DataFrame({
    'Student': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Math': [85, 90, 78, 92],
    'Physics': [88, 85, 90, 87],
    'Chemistry': [90, 88, 85, 89]
})
df30
# Out:
#   Student  Math  Physics  Chemistry
# 0     Ali    85       88         90
# 1    Vali    90       85         88
# 2  Sardor    78       90         85
# 3   Jasur    92       87         89

# %%
# Calculate each student's total score and average
num_cols = ['Math', 'Physics', 'Chemistry']
df30['Total'] = df30[num_cols].sum(axis=1)
df30['Mean'] = df30[num_cols].mean(axis=1)
df30
# Out:
#   Student  Math  Physics  Chemistry  Total       Mean
# 0     Ali    85       88         90    263  87.666667
# 1    Vali    90       85         88    263  87.666667
# 2  Sardor    78       90         85    253  84.333333
# 3   Jasur    92       87         89    268  89.333333

# %%
df31 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Age': [25, 30, 35, 28],
    'Salary': [5000, 6000, 5500, 7000]
})
df31
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500
# 3   Jasur   28    7000

# %%
# Extract general information about the DataFrame
df31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df32 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800],
    'Stock': [50, 120, 80, 200, 45],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Electronics']
})
df32
# Out:
#   Product  Price  Stock     Category
# 0  Laptop   1000     50  Electronics
# 1   Phone    500    120  Electronics
# 2  Tablet    300     80  Electronics
# 3   Watch    200    200  Accessories
# 4  Camera    800     45  Electronics

# %%
df32.shape
# Out:
# (5, 4)

# %%
df33 = pd.DataFrame({
    'Math': [85, 90, 78, 92, 88],
    'Physics': [88, 85, 90, 87, 91],
    'Chemistry': [90, 88, 85, 89, 86]
})
df33
# Out:
#    Math  Physics  Chemistry
# 0    85       88         90
# 1    90       85         88
# 2    78       90         85
# 3    92       87         89
# 4    88       91         86

# %%
# Output the correlation matrix between all subjects
df33.corr()
# Out:
#                Math   Physics  Chemistry
# Math       1.000000 -0.548606   0.556542
# Physics   -0.548606  1.000000  -0.636266
# Chemistry  0.556542 -0.636266   1.000000

# %%
df34 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Age': [25, 30, 35, 28, 32],
    'Salary': [5000, 6000, 5500, 7000, 6500]
})
df34
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500
# 3   Jasur   28    7000
# 4   Kamol   32    6500

# %%
# Filter employees with salary above 5500
df34[df34['Salary'] > 5500]
# Out:
#     Name  Age  Salary
# 1   Vali   30    6000
# 3  Jasur   28    7000
# 4  Kamol   32    6500

# %%
df35 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1000, 500, 300, 200, 800],
    'Stock': [50, 120, 80, 200, 45],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Electronics']
})
df35
# Out:
#   Product  Price  Stock     Category
# 0  Laptop   1000     50  Electronics
# 1   Phone    500    120  Electronics
# 2  Tablet    300     80  Electronics
# 3   Watch    200    200  Accessories
# 4  Camera    800     45  Electronics

# %%
# Find products in the Electronics category with less than 100 in stock
df35[(df35['Category'] == 'Electronics') & (df35['Stock'] < 100)]
# Out:
#   Product  Price  Stock     Category
# 0  Laptop   1000     50  Electronics
# 2  Tablet    300     80  Electronics
# 4  Camera    800     45  Electronics
