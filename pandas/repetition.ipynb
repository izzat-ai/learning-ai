# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/repetition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **`Series`**

# %%
# series yaratish usullari | py_list bilan
ser1 = pd.Series([1, 2.3, -4, 5, 'olti', 'minus_yetti'])
ser1

# %%
# series yaratishda index berish
ser2 = pd.Series(['bir', 'ikki', 'uch', 'tort', 'besh'], index=[1, 2, 3, 4, 5])
ser2

# %%
# py_dict yordamida series yaratish
dct1 = {'olma':4500, 'behi':2500, 'nok':4000, 'banan':8700}
ser3 = pd.Series(dct1)
ser3

# %%
# dct yordamida ikkinchi usul
ser4 = pd.Series({'Malibu':28_000, 'Onix':18_000, 'Monza':21_000, 'Tracker':23_000})
ser4

# %%
# 3-seriesdan faqatgina qiymatlarini olish
ser3.values

# %%
# 3-seriesdan faqatgina indekslarini olish
ser3.index

# %%
# 4-seriesdan indeks yordamida qiymatni olish
ser4['Monza']

# %%
ser4['Onix']

# %%
# tartib raqam orqali qiymat olish
ser4.iloc[1] # onix

# %%
ser4.iloc[0] # malibu

# %%
# Malibu va Onix qiymatlarini kesib olish
ser4['Malibu':'Onix']

# %%
ser4[0:2]

# %%
# narxi 21_000 dan kattalarni olish
ser4[ser4>21_000]

# %%
ser4.sum()

# %%
ser4.max()

# %%
ser4.min()

# %%
ser4.nunique()

# %%
ser4.isna()

# %% [markdown]
# *1-topshiriq*

# %%
products = pd.Series([
    "iPhone", "Samsung", "iPhone", "Xiaomi", "iPhone",
    "Samsung", "iPhone", "Xiaomi", "Samsung", "Samsung"
])
products

# %%
# mahsulotlar necha marta sotilganini aniqlash
products.value_counts()

# %%
temps = pd.Series([18, 19, None, 21, 500, 20, 19, None, 22, -100])
temps

# %%
temps =

# %%
temps.fillna(temps.mean())

# %%
temps.max()

# %%
temps.min()

# %%
temps[temps.mean()<temps]
