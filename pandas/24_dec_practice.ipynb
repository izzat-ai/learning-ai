# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/24_dec_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Ism": ["Ali", "Vali", "Hasan"],
    "Yosh": [20, 21, 19],
    "Ball": [85, 90, 78]
}
df = pd.DataFrame(data)
df
# Out:
#      Ism  Yosh  Ball
# 0    Ali    20    85
# 1   Vali    21    90
# 2  Hasan    19    78

# %%
# ustun nomlari
df.columns
# Out:
# Index(['Ism', 'Yosh', 'Ball'], dtype='object')

# %%
# qatorlar sonini aniqlash
df.shape
# Out:
# (3, 3)

# %%
# DF yaratish
data2 = {
    "A": {"2023": 120, "2024": 150},
    "B": {"2023": 200, "2024": 180}
}
df2 = pd.DataFrame(data2)
df2
# Out:
#         A    B
# 2023  120  200
# 2024  150  180

# %%
df3 = pd.DataFrame({
    "Mahsulot": ["Olma", "Banan", "Uzum"],
    "Narx": [8000, 12000, 10000]
})
df3
# Out:
#   Mahsulot   Narx
# 0     Olma   8000
# 1    Banan  12000
# 2     Uzum  10000

# %%
df3.index = ['a', 'b', 'c']
df3
# Out:
#   Mahsulot   Narx
# a     Olma   8000
# b    Banan  12000
# c     Uzum  10000

# %%
df4 = pd.DataFrame(
    {"Ball": [70, 85, 90]},
    index=["a", "b", "c"]
)
df4
# Out:
#    Ball
# a    70
# b    85
# c    90

# %%
# indekslarni 0 dan boshlanuvchi qilish
df4.reset_index()
# Out:
#   index  Ball
# 0     a    70
# 1     b    85
# 2     c    90

# %%
df5 = pd.DataFrame({
    "Ism": ["Ali", "Vali"],
    "Yosh": [20, 21],
    "Shahar": ["Toshkent", "Andijon"]
})
df5
# Out:
#     Ism  Yosh    Shahar
# 0   Ali    20  Toshkent
# 1  Vali    21   Andijon

# %%
# df5 dan Yosh ustunini olib tashlash
df5.drop(columns='Yosh')
# Out:
#     Ism    Shahar
# 0   Ali  Toshkent
# 1  Vali   Andijon

# %%
# df5dan 0-qatorni olib tashlash
df5.drop(0)
# Out:
#     Ism  Yosh   Shahar
# 1  Vali    21  Andijon

# %%
s = pd.Series([100, 200, 300], index=["A", "B", "C"])
s
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
# indeks bo'yicha bitta qiymat olish
s['B']
# Out:
# np.int64(200)

# %%
# 200 dan katta qiymatlarni olish
s[s>200]
# Out:
# C    300
# dtype: int64

# %%
df6 = pd.DataFrame({
    "Ism": ["Ali", "Vali", "Hasan"],
    "Matematika": [80, 90, 85],
    "Fizika": [75, 88, 82],
    "Ingliz tili": [70, 92, 78]
})
df6
# Out:
#      Ism  Matematika  Fizika  Ingliz tili
# 0    Ali          80      75           70
# 1   Vali          90      88           92
# 2  Hasan          85      82           78

# %%
# matematika va ingiliz tili ustunlarini tanlab olish
df6[['Matematika', 'Ingliz tili']]
# Out:
#    Matematika  Ingliz tili
# 0          80           70
# 1          90           92
# 2          85           78

# %%
# bali 85 dan katta talabalarni olish
df6[df6['Matematika'] > 85]
# Out:
#     Ism  Matematika  Fizika  Ingliz tili
# 1  Vali          90      88           92

# %%
df7 = pd.DataFrame({
    "A": [1, 2],
    "B": [3, 4]
}, index=["x", "y"])
df7
# Out:
#    A  B
# x  1  3
# y  2  4

# %%
# 3 qiymatini olish
df7.at['x', 'B']
# Out:
# np.int64(3)

# %%
# 2 qiymatini 22 ga o'zgartirish
df7.at['y', 'A'] = 22
df7
# Out:
#     A  B
# x   1  3
# y  22  4

# %%
df8 = pd.DataFrame({
    "A": [10, 20],
    "B": [30, 40]
})
df8
# Out:
#     A   B
# 0  10  30
# 1  20  40

# %%
# sonli ustunlarga 10 qo'shish
df8+10
# Out:
#     A   B
# 0  20  40
# 1  30  50

# %%
df8 * 2
# Out:
#     A   B
# 0  20  60
# 1  40  80

# %%
df9 = pd.DataFrame({
    "X": [1, 2, 3],
    "Y": [4, 5, 6]
})
df9
# Out:
#    X  Y
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df9.apply(lambda x: x**2)
# Out:
#    X   Y
# 0  1  16
# 1  4  25
# 2  9  36

# %%
# juft sonlarni o'zgartirib toq sonlarni qoldirish
np.where(df9%2==0, 0, df9)
# Out:
# array([[1, 0],
#        [0, 5],
#        [3, 0]])

# %%
df10 = pd.DataFrame({
    "Mahsulot": ["A", "B", "C"],
    "Narx": [12000, 8000, 10000]
})
df10
# Out:
#   Mahsulot   Narx
# 0        A  12000
# 1        B   8000
# 2        C  10000

# %%
# narxi bo'yicha o'sish tartibida joylashtirish
df10.sort_values(by='Narx')
# Out:
#   Mahsulot   Narx
# 1        B   8000
# 2        C  10000
# 0        A  12000

# %%
# ikkala ustun bo'yicha tartiblash
df10.sort_values(by=['Mahsulot', 'Narx'])
# Out:
#   Mahsulot   Narx
# 0        A  12000
# 1        B   8000
# 2        C  10000

# %%
df11 = pd.DataFrame({
    "Ism": ["Ali", "Vali", "Hasan"],
    "Ball": [85, 90, 78]
})
df11
# Out:
#      Ism  Ball
# 0    Ali    85
# 1   Vali    90
# 2  Hasan    78

# %%
# baliga qarab reytinglash
df11['Ball'].rank(ascending=False)
# Out:
# 0    2.0
# 1    1.0
# 2    3.0
# Name: Ball, dtype: float64

# %%
df12 = pd.DataFrame({
    "A": [5, 10, 15],
    "B": [2, 8, 20]
})
df12
# Out:
#     A   B
# 0   5   2
# 1  10   8
# 2  15  20

# %%
# eng katta va eng kichik qiymatlarni olish
print(np.max(df12))
print(np.min(df12))
# Out:
# 20
# 2

# %%
# har bir ustun uchun o'rtacha qiymatni aniqlash
df12.mean(axis=0)
# Out:
# A    10.0
# B    10.0
# dtype: float64

# %%
df13 = pd.DataFrame({
    "Sotuv": [100, 150, 200, 130],
    "Foyda": [20, 30, 50, 25]
})
df13
# Out:
#    Sotuv  Foyda
# 0    100     20
# 1    150     30
# 2    200     50
# 3    130     25

# %%
# umumiy statistik ma'lumotni olish
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sotuv   4 non-null      int64
#  1   Foyda   4 non-null      int64
# dtypes: int64(2)
# memory usage: 196.0 bytes

# %%
# faqatgina raqamli ustunlarni ma'lumotlarini olish
df13.describe()
# Out:
#             Sotuv      Foyda
# count    4.000000   4.000000
# mean   145.000000  31.250000
# std     42.031734  13.149778
# min    100.000000  20.000000
# 25%    122.500000  23.750000
# 50%    140.000000  27.500000
# 75%    162.500000  35.000000
# max    200.000000  50.000000

# %%
df14 = pd.DataFrame({
    "X": [1, 2, 3, 4, 5],
    "Y": [2, 4, 6, 8, 10],
    "Z": [5, 3, 6, 2, 1]
})
df14
# Out:
#    X   Y  Z
# 0  1   2  5
# 1  2   4  3
# 2  3   6  6
# 3  4   8  2
# 4  5  10  1

# %%
df14.corr()
# Out:
#           X         Y         Z
# X  1.000000  1.000000 -0.686244
# Y  1.000000  1.000000 -0.686244
# Z -0.686244 -0.686244  1.000000

# %%
df15 = pd.DataFrame({
    "Mahsulot": ["A", "B", "C", "D"],
    "Narx": [8000, 12000, 15000, 7000]
})
df15
# Out:
#   Mahsulot   Narx
# 0        A   8000
# 1        B  12000
# 2        C  15000
# 3        D   7000

# %%
# narxi 10_000 dan katta mahsulotlarni olish
df15[df15['Narx']>10_000]
# Out:
#   Mahsulot   Narx
# 1        B  12000
# 2        C  15000

# %%
df15[(df15['Narx']>8000) & (df15['Narx']<15000)]
# Out:
#   Mahsulot   Narx
# 1        B  12000

# %%
df16 = pd.DataFrame({
    "Ism": ["Ali", "Vali", "Hasan"],
    "Shahar": ["Toshkent", "Andijon", "Toshkent"],
    "Ball": [85, 90, 78]
})
df16
# Out:
#      Ism    Shahar  Ball
# 0    Ali  Toshkent    85
# 1   Vali   Andijon    90
# 2  Hasan  Toshkent    78

# %%
# faqatgina Toshkentga oid ma'lumotlarni olish
df16[df16['Shahar'] == 'Toshkent']
# Out:
#      Ism    Shahar  Ball
# 0    Ali  Toshkent    85
# 2  Hasan  Toshkent    78

# %%
# Toshkentdan tashqari ma'lumotlarni olish
df16[df16['Shahar'] != 'Toshkent']
# Out:
#     Ism   Shahar  Ball
# 1  Vali  Andijon    90

# %%
df17 = pd.DataFrame({
    "Ism": ["Ali", "Vali", "Hasan"],
    "Ball": [85, 90, 78]
})
df17
# Out:
#      Ism  Ball
# 0    Ali    85
# 1   Vali    90
# 2  Hasan    78

# %%
# bali eng past talabani olish
df17.loc[df17['Ball'].idxmin()]
# Out:
# Ism     Hasan
# Ball       78
# Name: 2, dtype: object

# %%
df18 = pd.DataFrame({
    "Mahsulot": ["Telefon", "Noutbuk", "Planshet"],
    "Narx": [2500000, 6000000, 3000000]
})
df18
# Out:
#    Mahsulot     Narx
# 0   Telefon  2500000
# 1   Noutbuk  6000000
# 2  Planshet  3000000

# %%
# eng arzon narxdagi mahsulotni olish
df18.loc[df18['Narx'].idxmin()]
# Out:
# Mahsulot    Telefon
# Narx        2500000
# Name: 0, dtype: object
