# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas/24_dec_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Ism": ["Ali", "Vali", "Hasan"],
    "Yosh": [20, 21, 19],
    "Ball": [85, 90, 78]
}
df = pd.DataFrame(data)
df
# Out:
#      Ism  Yosh  Ball
# 0    Ali    20    85
# 1   Vali    21    90
# 2  Hasan    19    78

# %%
# ustun nomlari
df.columns
# Out:
# Index(['Ism', 'Yosh', 'Ball'], dtype='object')

# %%
# qatorlar sonini aniqlash
df.shape
# Out:
# (3, 3)

# %%
# DF yaratish
data2 = {
    "A": {"2023": 120, "2024": 150},
    "B": {"2023": 200, "2024": 180}
}
df2 = pd.DataFrame(data2)
df2
# Out:
#         A    B
# 2023  120  200
# 2024  150  180

# %%
df3 = pd.DataFrame({
    "Mahsulot": ["Olma", "Banan", "Uzum"],
    "Narx": [8000, 12000, 10000]
})
df3
# Out:
#   Mahsulot   Narx
# 0     Olma   8000
# 1    Banan  12000
# 2     Uzum  10000

# %%
df3.index = ['a', 'b', 'c']
df3
# Out:
#   Mahsulot   Narx
# a     Olma   8000
# b    Banan  12000
# c     Uzum  10000

# %%
df4 = pd.DataFrame(
    {"Ball": [70, 85, 90]},
    index=["a", "b", "c"]
)
df4
# Out:
#    Ball
# a    70
# b    85
# c    90

# %%
# indekslarni 0 dan boshlanuvchi qilish
df4.reset_index()
# Out:
#   index  Ball
# 0     a    70
# 1     b    85
# 2     c    90

# %%
df5 = pd.DataFrame({
    "Ism": ["Ali", "Vali"],
    "Yosh": [20, 21],
    "Shahar": ["Toshkent", "Andijon"]
})
df5
# Out:
#     Ism  Yosh    Shahar
# 0   Ali    20  Toshkent
# 1  Vali    21   Andijon

# %%
# df5 dan Yosh ustunini olib tashlash
df5.drop(columns='Yosh')
# Out:
#     Ism    Shahar
# 0   Ali  Toshkent
# 1  Vali   Andijon

# %%
# df5dan 0-qatorni olib tashlash
df5.drop(0)
# Out:
#     Ism  Yosh   Shahar
# 1  Vali    21  Andijon

# %%
s = pd.Series([100, 200, 300], index=["A", "B", "C"])
s
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
# indeks bo'yicha bitta qiymat olish
s['B']
# Out:
# np.int64(200)

# %%
# 200 dan katta qiymatlarni olish
s[s>200]
# Out:
# C    300
# dtype: int64

# %%
df6 = pd.DataFrame({
    "Ism": ["Ali", "Vali", "Hasan"],
    "Matematika": [80, 90, 85],
    "Fizika": [75, 88, 82],
    "Ingliz tili": [70, 92, 78]
})
df6
# Out:
#      Ism  Matematika  Fizika  Ingliz tili
# 0    Ali          80      75           70
# 1   Vali          90      88           92
# 2  Hasan          85      82           78

# %%
# matematika va ingiliz tili ustunlarini tanlab olish
df6[['Matematika', 'Ingliz tili']]
# Out:
#    Matematika  Ingliz tili
# 0          80           70
# 1          90           92
# 2          85           78

# %%
# 14-topshiriqni javobini yozishim kerak

# %%
df7 = pd.DataFrame({
    "A": [1, 2],
    "B": [3, 4]
}, index=["x", "y"])
df7
# Out:
#    A  B
# x  1  3
# y  2  4

# %%
# 3 qiymatini olish
df7.at['x', 'B']
# Out:
# np.int64(3)

# %%
# 2 qiymatini 22 ga o'zgartirish
df7.at['y', 'A'] = 22
df7
# Out:
#     A  B
# x   1  3
# y  22  4

# %%
df8 = pd.DataFrame({
    "A": [10, 20],
    "B": [30, 40]
})
df8
# Out:
#     A   B
# 0  10  30
# 1  20  40

# %%
# sonli ustunlarga 10 qo'shish
df8+10
# Out:
#     A   B
# 0  20  40
# 1  30  50

# %%
df8 * 2
# Out:
#     A   B
# 0  20  60
# 1  40  80

# %%
df9 = pd.DataFrame({
    "X": [1, 2, 3],
    "Y": [4, 5, 6]
})
df9
# Out:
#    X  Y
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df9.apply(lambda x: x**2)
# Out:
#    X   Y
# 0  1  16
# 1  4  25
# 2  9  36

# %%
# juft sonlarni o'zgartirib toq sonlarni qoldirish
np.where(df9%2==0, 0, df9)
# Out:
# array([[1, 0],
#        [0, 5],
#        [3, 0]])
