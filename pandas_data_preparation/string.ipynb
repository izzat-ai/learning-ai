# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas_data_preparation/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Full_Name': ['Mr. Ahmed Ali', 'Dr. Sara Khan', 'Ms. Fatima Rahman'],
    'Email': ['ahmed.ali@company.com', 'sara.khan@tech.org', 'fatima.r@startup.io'],
    'Phone': ['(998) 90-123-4567', '998-91-234-5678', '998 93 345 6789']
})
df
# Out:
#            Full_Name                  Email              Phone
# 0      Mr. Ahmed Ali  ahmed.ali@company.com  (998) 90-123-4567
# 1      Dr. Sara Khan     sara.khan@tech.org    998-91-234-5678
# 2  Ms. Fatima Rahman    fatima.r@startup.io    998 93 345 6789

# %%
# Remove titles like "Mr.", "Dr.", "Ms." from Full_Name
df['Full_Name'] = df['Full_Name'].str.split('.').str[1]
df
# Out:
#         Full_Name                  Email              Phone
# 0       Ahmed Ali  ahmed.ali@company.com  (998) 90-123-4567
# 1       Sara Khan     sara.khan@tech.org    998-91-234-5678
# 2   Fatima Rahman    fatima.r@startup.io    998 93 345 6789

# %%
# Extract only the username part from the email
df['Email'] = df['Email'].str.split('@').str[0]
df
# Out:
#         Full_Name      Email              Phone
# 0       Ahmed Ali  ahmed.ali  (998) 90-123-4567
# 1       Sara Khan  sara.khan    998-91-234-5678
# 2   Fatima Rahman   fatima.r    998 93 345 6789

# %%
# Convert phone numbers to numbers only
df['Phone'] = df['Phone'].replace(r'\D', '', regex=True)
df
# Out:
#         Full_Name      Email         Phone
# 0       Ahmed Ali  ahmed.ali  998901234567
# 1       Sara Khan  sara.khan  998912345678
# 2   Fatima Rahman   fatima.r  998933456789

# %%
df1 = pd.DataFrame({
    'Product_Code': ['ELEC-LAP-001', 'FURN-CHA-002', 'ELEC-PHO-003', 'FURN-TAB-004'],
    'Description': ['  High Performance Laptop  ', 'ERGONOMIC OFFICE CHAIR', '  smartphone 5G  ', 'wooden table'],
    'Category': ['Electronics', 'Furniture', 'Electronics', 'Furniture']
})
df1
# Out:
#    Product_Code                  Description     Category
# 0  ELEC-LAP-001    High Performance Laptop    Electronics
# 1  FURN-CHA-002       ERGONOMIC OFFICE CHAIR    Furniture
# 2  ELEC-PHO-003              smartphone 5G    Electronics
# 3  FURN-TAB-004                 wooden table    Furniture

# %%
# Extract the first part from Product_Code (ELEC, FURN
df1['Product_Code'].str.split('-').str[0]
# Out:
# 0    ELEC
# 1    FURN
# 2    ELEC
# 3    FURN
# Name: Product_Code, dtype: object

# %%
# Remove spaces from Description and capitalize the first letter of each word
df1['Description'] = df1['Description'].str.strip()
df1['Description'] = df1['Description'].str.capitalize()
df1
# Out:
#    Product_Code              Description     Category
# 0  ELEC-LAP-001  High performance laptop  Electronics
# 1  FURN-CHA-002   Ergonomic office chair    Furniture
# 2  ELEC-PHO-003            Smartphone 5g  Electronics
# 3  FURN-TAB-004             Wooden table    Furniture

# %%
df1[df1['Category'].str.len() > 10] = 'Long'
# Out:
#    Product_Code              Description     Category
# 0  ELEC-LAP-001  High performance laptop  Electronics
# 2  ELEC-PHO-003            Smartphone 5g  Electronics
