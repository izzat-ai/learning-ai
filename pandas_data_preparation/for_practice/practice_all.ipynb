# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas_data_preparation/for_practice/practice_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)

# %%
df1 = pd.DataFrame({
    "product": ["Phone","Laptop","Tablet","Monitor","Keyboard"],
    "price": [1200, None, 600, None, 80],
    "quantity": [5, 3, None, 4, 10]
})
df1
# Out:
#     product   price  quantity
# 0     Phone  1200.0       5.0
# 1    Laptop     NaN       3.0
# 2    Tablet   600.0       NaN
# 3   Monitor     NaN       4.0
# 4  Keyboard    80.0      10.0

# %%
# Determine how many blank values ​​are in which columns
df1.isnull().sum()
# Out:
# product     0
# price       2
# quantity    1
# dtype: int64

# %%
# Check if total revenue is being calculated incorrectly due to empty values
df1['price'] * df1['quantity']
# Out:
# 0    6000.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4     800.0
# dtype: float64

# %%
df1 = df1.dropna().copy()
df1
# Out:
#     product   price  quantity
# 0     Phone  1200.0       5.0
# 4  Keyboard    80.0      10.0

# %%
# recalculate total revenue based on the cleaned dataset
df1['revenue'] = df1['price'] * df1['quantity']
df1
# Out:
#     product   price  quantity  revenue
# 0     Phone  1200.0       5.0   6000.0
# 4  Keyboard    80.0      10.0    800.0

# %%
df2 = pd.DataFrame({
    "student": ["Ali","Vali","Ali","Hasan","Vali","Zafar"],
    "math": [85, 90, 85, 70, 90, 88]
})
df2
# Out:
#   student  math
# 0     Ali    85
# 1    Vali    90
# 2     Ali    85
# 3   Hasan    70
# 4    Vali    90
# 5   Zafar    88

# %%
# Identify duplicate entries
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
# Remove duplicate rows and determine how many unique students remain
len(df2.drop_duplicates())
# Out:
# 4

# %%
df3 = pd.DataFrame({
    "gender": ["M","F","M","F","F","M"],
    "score": [78, 88, 90, 67, 95, 80]
})
df3
# Out:
#   gender  score
# 0      M     78
# 1      F     88
# 2      M     90
# 3      F     67
# 4      F     95
# 5      M     80

# %%
# Convert the values ​​in the Gender column to full word form
df3['gender'] = df3['gender'].replace({'M':'male', 'F':'female'})
df3
# Out:
#    gender  score
# 0    male     78
# 1  female     88
# 2    male     90
# 3  female     67
# 4  female     95
# 5    male     80

# %%
# Change values ​​below 80 in the Score column to “Low”, otherwise to “High”
df3['score'].map(lambda x: 'low' if x<80 else 'high')
# Out:
# 0     low
# 1    high
# 2    high
# 3     low
# 4    high
# 5    high
# Name: score, dtype: object

# %%
df4 = pd.DataFrame({
    "age": [15, 22, 37, 45, 18, 29, 60]
})
df4
# Out:
#    age
# 0   15
# 1   22
# 2   37
# 3   45
# 4   18
# 5   29
# 6   60

# %%
# Divide the ages into 3 intervals and count how many people are in each interval
bins = [14, 24, 44, 65]
df4['groups'] = pd.cut(df4['age'], bins, labels=['teenagers', 'middle-age', 'adults'])
df4
# Out:
#    age      groups
# 0   15   teenagers
# 1   22   teenagers
# 2   37  middle-age
# 3   45      adults
# 4   18   teenagers
# 5   29  middle-age
# 6   60      adults

# %%
df4['groups'].value_counts()
# Out:
# groups
# teenagers     3
# middle-age    2
# adults        2
# Name: count, dtype: int64

# %%
df5 = pd.DataFrame({
    "region": np.random.choice(["Toshkent","Samarqand","Buxoro"], 15),
    "sales": np.random.randint(1000, 5000, 15)
})
df5
# Out:
#        region  sales
# 0      Buxoro   4380
# 1    Toshkent   1769
# 2      Buxoro   3391
# 3      Buxoro   2515
# 4    Toshkent   4485
# 5    Toshkent   3853
# 6      Buxoro   3433
# 7   Samarqand   2215
# 8      Buxoro   1955
# 9      Buxoro   3324
# 10     Buxoro   2184
# 11     Buxoro   1459
# 12   Toshkent   4385
# 13     Buxoro   1021
# 14  Samarqand   3300

# %%
# Calculate the average sales for each region
df5.groupby('region')['sales'].mean()
# Out:
# region
# Buxoro       2629.111111
# Samarqand    2757.500000
# Toshkent     3623.000000
# Name: sales, dtype: float64

# %%
# Calculate the average sales for each region
df5.groupby('region')['sales'].sum().idxmax()
# Out:
# 'Buxoro'

# %%
df6 = pd.DataFrame({
    "income": [2000, 3000, 15000, 2500, 4000, 50000, 2700]
})
df6
# Out:
#    income
# 0    2000
# 1    3000
# 2   15000
# 3    2500
# 4    4000
# 5   50000
# 6    2700

# %%
# sort data
df6_sort = df6.sort_values(by='income', ascending=True)
df6_sort
# Out:
#    income
# 0    2000
# 3    2500
# 6    2700
# 1    3000
# 4    4000
# 2   15000
# 5   50000

# %% [markdown]
# - `IQR = Q3 - Q1`
# - `Q1` - 25% , `Q3` - 75%

# %%
df6_sort.describe()
# Out:
#              income
# count      7.000000
# mean   11314.285714
# std    17660.920000
# min     2000.000000
# 25%     2600.000000
# 50%     3000.000000
# 75%     9500.000000
# max    50000.000000

# %%
# Outlier detection using the IQR method
q1 = 2600
q3 = 9500
iqr = q3 - q1
up = q3 + (1.5 * iqr)
low = q1 - (1.5 * iqr) # If the answer is a negative number, it is taken as 0
print("upper: ", up)
print('lower: ', low)
# Out:
# upper:  19850.0
# lower:  -7750.0

# %% [markdown]
# - There are only 50000 above 19850. Therefore, the outlier in our data is only 50000.

# %%
# determining the mean value together with the outlier
df6_sort['income'].mean()
# Out:
# np.float64(11314.285714285714)

# %%
# Removing extreme values
df6_sort[df6_sort['income'] > 19850]
# Out:
#    income
# 5   50000

# %%
df6_sort = df6_sort.drop(5)
df6_sort
# Out:
#    income
# 0    2000
# 3    2500
# 6    2700
# 1    3000
# 4    4000
# 2   15000

# %%
# determining the average value without outliers
df6_sort['income'].mean()
# Out:
# np.float64(4866.666666666667)

# %%
df7 = pd.DataFrame({
    "order_id": range(1, 21),
    "amount": np.random.randint(100, 1000, 20)
})
df7
# Out:
#     order_id  amount
# 0          1     847
# 1          2     956
# 2          3     660
# 3          4     574
# 4          5     158
# 5          6     610
# 6          7     781
# 7          8     575
# 8          9     799
# 9         10     882
# 10        11     289
# 11        12     786
# 12        13     662
# 13        14     975
# 14        15     666
# 15        16     343
# 16        17     931
# 17        18     604
# 18        19     230
# 19        20     584

# %%
# Extract 5 random orders from the table
df7_sample = df7.sample(5)
df7_sample
# Out:
#     order_id  amount
# 10        11     289
# 7          8     575
# 0          1     847
# 2          3     660
# 5          6     610

# %%
# Calculate the average sum of randomly selected orders
df7_sample['amount'].mean()
# Out:
# np.float64(596.2)

# %%
df8 = pd.DataFrame({
    "date": ["2025-01-05","2025-02-10","2025-03-15","2025-04-20"],
    "sales": [1000,1500,1200,1800]
})
df8
# Out:
#          date  sales
# 0  2025-01-05   1000
# 1  2025-02-10   1500
# 2  2025-03-15   1200
# 3  2025-04-20   1800

# %%
# Convert a date column to time format
df8['date'] = pd.to_datetime(df8['date'])
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4 non-null      datetime64[ns]
#  1   sales   4 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 196.0 bytes

# %%
# separate the year as a separate column
df8['year'] = df8['date'].dt.year
df8
# Out:
#         date  sales  year
# 0 2025-01-05   1000  2025
# 1 2025-02-10   1500  2025
# 2 2025-03-15   1200  2025
# 3 2025-04-20   1800  2025

# %%
# Summarize sales by month
df8['month'] = df8['date'].dt.month_name()
df8.groupby('month')['sales'].sum()
# Out:
# month
# April       1800
# February    1500
# January     1000
# March       1200
# Name: sales, dtype: int64

# %%
df9 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Age': [25, np.nan, 35, 28, np.nan],
    'Salary': [5000, 6000, np.nan, 7000, 6500],
    'City': ['Tashkent', 'Samarkand', np.nan, 'Bukhara', 'Fergana']
})
df9
# Out:
#      Name   Age  Salary       City
# 0     Ali  25.0  5000.0   Tashkent
# 1    Vali   NaN  6000.0  Samarkand
# 2  Sardor  35.0     NaN        NaN
# 3   Jasur  28.0  7000.0    Bukhara
# 4   Kamol   NaN  6500.0    Fergana

# %%
# Delete rows with all NaN values
df9.dropna()
# Out:
#     Name   Age  Salary      City
# 0    Ali  25.0  5000.0  Tashkent
# 3  Jasur  28.0  7000.0   Bukhara

# %%
df10 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch', 'Camera'],
    'Price': [1200, np.nan, 450, 250, np.nan],
    'Stock': [50, 120, np.nan, 200, 45],
    'Rating': [4.5, 4.7, np.nan, 4.0, 4.8]
})
df10
# Out:
#   Product   Price  Stock  Rating
# 0  Laptop  1200.0   50.0     4.5
# 1   Phone     NaN  120.0     4.7
# 2  Tablet   450.0    NaN     NaN
# 3   Watch   250.0  200.0     4.0
# 4  Camera     NaN   45.0     4.8

# %%
# Delete rows with at least 2 NaN values
df10.dropna(thresh=3)
# Out:
#   Product   Price  Stock  Rating
# 0  Laptop  1200.0   50.0     4.5
# 1   Phone     NaN  120.0     4.7
# 3   Watch   250.0  200.0     4.0
# 4  Camera     NaN   45.0     4.8

# %%
df11 = pd.DataFrame({
    'Student': ['Ahmad', 'Zarina', 'Bekzod', 'Dilshod'],
    'Math': [85, np.nan, 78, 92],
    'Physics': [88, 85, np.nan, 87],
    'Chemistry': [90, 88, 85, np.nan]
})
df11
# Out:
#    Student  Math  Physics  Chemistry
# 0    Ahmad  85.0     88.0       90.0
# 1   Zarina   NaN     85.0       88.0
# 2   Bekzod  78.0      NaN       85.0
# 3  Dilshod  92.0     87.0        NaN

# %%
# Delete rows with NaN values ​​in all columns
df11.dropna(axis=1)
# Out:
#    Student
# 0    Ahmad
# 1   Zarina
# 2   Bekzod
# 3  Dilshod

# %%
df12 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur', 'Kamol'],
    'Age': [25, np.nan, 35, 28, np.nan],
    'Salary': [5000, 6000, np.nan, 7000, 6500],
    'Experience': [3, 5, np.nan, 4, 6]
})
df12
# Out:
#      Name   Age  Salary  Experience
# 0     Ali  25.0  5000.0         3.0
# 1    Vali   NaN  6000.0         5.0
# 2  Sardor  35.0     NaN         NaN
# 3   Jasur  28.0  7000.0         4.0
# 4   Kamol   NaN  6500.0         6.0

# %%
# Fill in NaN values ​​in the Age column with the average value
df12['Age'] = df12['Age'].fillna(df12['Age'].mean())
df12
# Out:
#      Name        Age  Salary  Experience
# 0     Ali  25.000000  5000.0         3.0
# 1    Vali  29.333333  6000.0         5.0
# 2  Sardor  35.000000     NaN         NaN
# 3   Jasur  28.000000  7000.0         4.0
# 4   Kamol  29.333333  6500.0         6.0

# %%
# Fill in NaN values ​​in the Salary column with the median
df12['Salary'] = df12['Salary'].fillna(df12['Salary'].median())
df12
# Out:
#      Name        Age  Salary  Experience
# 0     Ali  25.000000  5000.0         3.0
# 1    Vali  29.333333  6000.0         5.0
# 2  Sardor  35.000000  6250.0         NaN
# 3   Jasur  28.000000  7000.0         4.0
# 4   Kamol  29.333333  6500.0         6.0

# %%
df13 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch'],
    'Price': [1200, np.nan, 450, 250],
    'Category': ['Electronics', np.nan, 'Electronics', 'Accessories'],
    'Rating': [4.5, 4.7, np.nan, 4.0]
})
df13
# Out:
#   Product   Price     Category  Rating
# 0  Laptop  1200.0  Electronics     4.5
# 1   Phone     NaN          NaN     4.7
# 2  Tablet   450.0  Electronics     NaN
# 3   Watch   250.0  Accessories     4.0

# %%
# Fill NaN values ​​in the Price column with 0
df13['Price'].fillna(0)
# Out:
# 0    1200.0
# 1       0.0
# 2     450.0
# 3     250.0
# Name: Price, dtype: float64

# %%
# Fill in NaN values ​​in the Category column with 'Unknown'
df13['Category'].fillna('Unknown')
# Out:
# 0    Electronics
# 1        Unknown
# 2    Electronics
# 3    Accessories
# Name: Category, dtype: object

# %%
# Fill in NaN values ​​in the Rating column with the previous one
df13['Rating'].bfill()
# Out:
# 0    4.5
# 1    4.7
# 2    4.0
# 3    4.0
# Name: Rating, dtype: float64

# %%
df14 = pd.DataFrame({
    'Student': ['Ahmad', 'Zarina', 'Bekzod', 'Dilshod', 'Eldor'],
    'Math': [85, np.nan, 78, 92, 88],
    'Physics': [88, 85, np.nan, 87, 91],
    'Chemistry': [90, 88, 85, np.nan, 86]
})
df14
# Out:
#    Student  Math  Physics  Chemistry
# 0    Ahmad  85.0     88.0       90.0
# 1   Zarina   NaN     85.0       88.0
# 2   Bekzod  78.0      NaN       85.0
# 3  Dilshod  92.0     87.0        NaN
# 4    Eldor  88.0     91.0       86.0

# %%
# Fill in NaN values ​​in each column with the average value of that column
mean = df14.select_dtypes(include='number').mean()
df14.fillna(mean)
# Out:
#    Student   Math  Physics  Chemistry
# 0    Ahmad  85.00    88.00      90.00
# 1   Zarina  85.75    85.00      88.00
# 2   Bekzod  78.00    87.75      85.00
# 3  Dilshod  92.00    87.00      87.25
# 4    Eldor  88.00    91.00      86.00

# %%
df15 = pd.DataFrame({
    'OrderID': [1001, 1002, 1001, 1003, 1002, 1001],
    'Customer': ['Ali', 'Vali', 'Ali', 'Sardor', 'Vali', 'Ali'],
    'Product': ['Laptop', 'Phone', 'Laptop', 'Tablet', 'Phone', 'Laptop'],
    'Amount': [1500, 800, 1500, 450, 800, 1500]
})
df15
# Out:
#    OrderID Customer Product  Amount
# 0     1001      Ali  Laptop    1500
# 1     1002     Vali   Phone     800
# 2     1001      Ali  Laptop    1500
# 3     1003   Sardor  Tablet     450
# 4     1002     Vali   Phone     800
# 5     1001      Ali  Laptop    1500

# %%
# Check for duplicate rows and output their number
df15.duplicated().sum()
# Out:
# np.int64(3)

# %%
df16 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Ali', 'Sardor', 'Vali', 'Jasur'],
    'Department': ['IT', 'HR', 'IT', 'Sales', 'HR', 'IT'],
    'Salary': [5000, 6000, 5000, 4500, 6000, 7000]
})
df16
# Out:
#      Name Department  Salary
# 0     Ali         IT    5000
# 1    Vali         HR    6000
# 2     Ali         IT    5000
# 3  Sardor      Sales    4500
# 4    Vali         HR    6000
# 5   Jasur         IT    7000

# %%
# Delete all duplicate rows
df16.drop_duplicates()
# Out:
#      Name Department  Salary
# 0     Ali         IT    5000
# 1    Vali         HR    6000
# 3  Sardor      Sales    4500
# 5   Jasur         IT    7000

# %%
df17 = pd.DataFrame({
    'Student': ['Ahmad', 'Zarina', 'Ahmad', 'Bekzod', 'Zarina'],
    'Subject': ['Math', 'Physics', 'Physics', 'Chemistry', 'Physics'],
    'Score': [85, 92, 78, 88, 92]
})
df17
# Out:
#   Student    Subject  Score
# 0   Ahmad       Math     85
# 1  Zarina    Physics     92
# 2   Ahmad    Physics     78
# 3  Bekzod  Chemistry     88
# 4  Zarina    Physics     92

# %%
df17.drop_duplicates(subset=['Student', 'Subject'])
# Out:
#   Student    Subject  Score
# 0   Ahmad       Math     85
# 1  Zarina    Physics     92
# 2   Ahmad    Physics     78
# 3  Bekzod  Chemistry     88

# %%
new_df17 = df17[df17.duplicated(keep=False)]
new_df17
# Out:
#   Student  Subject  Score
# 1  Zarina  Physics     92
# 4  Zarina  Physics     92

# %%
df18 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch'],
    'Price': [1200, 800, 450, 250],
    'Stock': [50, 120, 80, 200]
})
df18
# Out:
#   Product  Price  Stock
# 0  Laptop   1200     50
# 1   Phone    800    120
# 2  Tablet    450     80
# 3   Watch    250    200

# %%
# Change the values ​​in the Price column to Price_USD and Stock to Quantity
df18.rename(columns={'Price':'Price_USD', 'Stock':'Quantity'})
# Out:
#   Product  Price_USD  Quantity
# 0  Laptop       1200        50
# 1   Phone        800       120
# 2  Tablet        450        80
# 3   Watch        250       200

# %%
df19 = pd.DataFrame({
    'old_name': ['Ali', 'Vali', 'Sardor'],
    'old_age': [25, 30, 35],
    'old_salary': [5000, 6000, 5500]
})
df19
# Out:
#   old_name  old_age  old_salary
# 0      Ali       25        5000
# 1     Vali       30        6000
# 2   Sardor       35        5500

# %%
# Remove the 'old_' prefix from all column names
df19.columns = df19.columns.str.replace('old_', '')
df19
# Out:
#      name  age  salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500

# %%
# Change column names to uppercase
df19.columns = df19.columns.str.upper()
df19
# Out:
#      NAME  AGE  SALARY
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500

# %%
df20 = pd.DataFrame({
    'ProductName': ['Laptop', 'Phone', 'Tablet'],
    'ProductPrice': [1200, 800, 450],
    'ProductStock': [50, 120, 80]
})
df20
# Out:
#   ProductName  ProductPrice  ProductStock
# 0      Laptop          1200            50
# 1       Phone           800           120
# 2      Tablet           450            80

# %%
# Make all column names lowercase and remove the word 'Product'
df20.columns = df20.columns.str.replace('Product', '').str.lower()
df20
# Out:
#      name  price  stock
# 0  Laptop   1200     50
# 1   Phone    800    120
# 2  Tablet    450     80

# %%
df21 = pd.DataFrame({
    'Name': ['Ali', 'Vali', 'Sardor', 'Jasur'],
    'Age': [25, 30, 35, 28],
    'Salary': [5000, 6000, 5500, 7000]
})
df21
# Out:
#      Name  Age  Salary
# 0     Ali   25    5000
# 1    Vali   30    6000
# 2  Sardor   35    5500
# 3   Jasur   28    7000

# %%
# Separate the Salary column into a new DataFrame and delete it from the original DataFrame
df21_col = df21.pop('Salary')
df21_col
# Out:
# 0    5000
# 1    6000
# 2    5500
# 3    7000
# Name: Salary, dtype: int64

# %%
df21
# Out:
#      Name  Age
# 0     Ali   25
# 1    Vali   30
# 2  Sardor   35
# 3   Jasur   28

# %%
df22 = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Watch'],
    'Price': [1200, 800, 450, 250],
    'Stock': [50, 120, 80, 200],
    'Rating': [4.5, 4.7, 4.2, 4.0]
})
df22
# Out:
#   Product  Price  Stock  Rating
# 0  Laptop   1200     50     4.5
# 1   Phone    800    120     4.7
# 2  Tablet    450     80     4.2
# 3   Watch    250    200     4.0

# %%
# Split the Price and Stock columns into a new DataFrame
new_df22 = df22[['Price', 'Stock']]
new_df22
# Out:
#    Price  Stock
# 0   1200     50
# 1    800    120
# 2    450     80
# 3    250    200

# %%
# Delete the Rating column from the original DataFrame
del df22['Rating']

# %%
df23 = pd.DataFrame({
    'Student': ['Ahmad', 'Zarina', 'Bekzod'],
    'Math': [85, 92, 78],
    'Physics': [88, 85, 90],
    'Chemistry': [90, 88, 85]
})
df23
# Out:
#   Student  Math  Physics  Chemistry
# 0   Ahmad    85       88         90
# 1  Zarina    92       85         88
# 2  Bekzod    78       90         85

# %%
# Separate the Math and Physics columns into one new DataFrame, and Chemistry into a separate DataFrame
math_phy = df23.drop(columns=['Math', 'Physics'])
#chem = df23.pop('Chemistry')

print(math_phy)
# Out:
#   Student  Chemistry
# 0   Ahmad         90
# 1  Zarina         88
# 2  Bekzod         85

# %%
df24 = pd.DataFrame({
    'Name': ['Ali Khan Ahmad', 'Vali Karimov', 'Sardor Toshmatov Aliyev'],
    'Email': ['ali@example.com', 'vali@test.org', 'sardor@company.uz'],
    'Phone': ['+998901234567', '998-90-123-4568', '998 91 234 5678']
})
df24
# Out:
#                       Name              Email            Phone
# 0           Ali Khan Ahmad    ali@example.com    +998901234567
# 1             Vali Karimov      vali@test.org  998-90-123-4568
# 2  Sardor Toshmatov Aliyev  sardor@company.uz  998 91 234 5678

# %%
# Separate domain names from the email column and create a new column
df24['Domen_email'] = df24['Email'].str.split('@').str[1]
df24
# Out:
#                       Name              Email            Phone  Domen_email
# 0           Ali Khan Ahmad    ali@example.com    +998901234567  example.com
# 1             Vali Karimov      vali@test.org  998-90-123-4568     test.org
# 2  Sardor Toshmatov Aliyev  sardor@company.uz  998 91 234 5678   company.uz

# %%
# Remove all characters and spaces from the Phone column
df24['New_phone'] = df24['Phone'].str.replace(r'[^\w\s]', '', regex=True)
df24
# Out:
#                       Name              Email            Phone  Domen_email  \
# 0           Ali Khan Ahmad    ali@example.com    +998901234567  example.com
# 1             Vali Karimov      vali@test.org  998-90-123-4568     test.org
# 2  Sardor Toshmatov Aliyev  sardor@company.uz  998 91 234 5678   company.uz
#
#          New_phone
# 0     998901234567
# 1     998901234568
# 2  998 91 234 5678

# %%
# Capitalize the first letter of each word in the Name column
df24['New_name'] = df24['Name'].str.title()
df24
# Out:
#                       Name              Email            Phone  Domen_email  \
# 0           Ali Khan Ahmad    ali@example.com    +998901234567  example.com
# 1             Vali Karimov      vali@test.org  998-90-123-4568     test.org
# 2  Sardor Toshmatov Aliyev  sardor@company.uz  998 91 234 5678   company.uz
#
#          New_phone                 New_name
# 0     998901234567           Ali Khan Ahmad
# 1     998901234568             Vali Karimov
# 2  998 91 234 5678  Sardor Toshmatov Aliyev

# %%
df25 = pd.DataFrame({
    'Product_Code': ['ELEC-LAP-001', 'FURN-CHA-002', 'ELEC-PHO-003'],
    'Description': ['  High Performance  ', 'OFFICE CHAIR', '  smartphone  '],
    'Status': ['active_user', 'inactive_user', 'pending_user']
})
df25
# Out:
#    Product_Code           Description         Status
# 0  ELEC-LAP-001    High Performance      active_user
# 1  FURN-CHA-002          OFFICE CHAIR  inactive_user
# 2  ELEC-PHO-003          smartphone     pending_user

# %%
# Extract the first part from Product_Code (ELEC, FURN)
df25['Product_Code'].str.split('-').str[0]
# Out:
# 0    ELEC
# 1    FURN
# 2    ELEC
# Name: Product_Code, dtype: object

# %%
# Remove spaces in Description and make Title Case
df25['Description'].str.replace(r'\s+', '', regex=True).str.title()
# Out:
# 0    Highperformance
# 1        Officechair
# 2         Smartphone
# Name: Description, dtype: object

# %%
# Remove the '_user' part from Status
df25['Status'].str.split('_').str[0]
# Out:
# 0      active
# 1    inactive
# 2     pending
# Name: Status, dtype: object

# %%
df26 = pd.DataFrame({
    'Username': ['user_ali123', 'admin_vali', 'guest_sardor'],
    'Text': ['Hello World!', 'PYTHON PROGRAMMING', 'Data Science'],
    'Code': ['USR-001-ACTIVE', 'ADM-002-INACTIVE', 'GST-003-PENDING']
})
df26
# Out:
#        Username                Text              Code
# 0   user_ali123        Hello World!    USR-001-ACTIVE
# 1    admin_vali  PYTHON PROGRAMMING  ADM-002-INACTIVE
# 2  guest_sardor        Data Science   GST-003-PENDING

# %%
# Remove the prefixes 'user_', 'admin_', 'guest_' from the username
df26['Username'].str.split('_').str[1]
# Out:
# 0    ali123
# 1      vali
# 2    sardor
# Name: Username, dtype: object

# %%
# Change the Text column to lowercase
df26['Text'].str.lower()
# Out:
# 0          hello world!
# 1    python programming
# 2          data science
# Name: Text, dtype: object

# %%
# Extract only the numeric part from the code
df26['Code'].str.split('-').str[1]
# Out:
# 0    001
# 1    002
# 2    003
# Name: Code, dtype: object
