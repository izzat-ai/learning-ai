# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/pandas_data_preparation/fillna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Savdo_Xodimi': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
    'Ball': [88, 92, np.nan, 75, 80, np.nan, 95, 78],  # Raqamli ustun (mean bilan to'ldirish)
    'Sotuv_soni': [15, np.nan, 18, 20, np.nan, 22, 25, 14],
    'Tashrif': [5, 6, 4, np.nan, 7, 5, np.nan, 6],
    'Shahar': ['Toshkent', np.nan, 'Buxoro', 'Samarqand', np.nan, 'Toshkent', 'Buxoro', np.nan], # Nomli ustun (ffill/bfill bilan to'ldirish)
    'Mijoz_Turi': ['Kichik', 'Katta', np.nan, 'Katta', 'Kichik', 'Katta', 'Kichik', np.nan],
    'Kanal': [1, 2, 1, 3, 2, np.nan, 1, 3] # Diskret raqamli ustun (median/mode bilan to'ldirish)
}
df = pd.DataFrame(data)
df
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C   NaN        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F   NaN        22.0      5.0   Toshkent      Katta    NaN
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Savdo_Xodimi  8 non-null      object
#  1   Ball          6 non-null      float64
#  2   Sotuv_soni    6 non-null      float64
#  3   Tashrif       6 non-null      float64
#  4   Shahar        5 non-null      object
#  5   Mijoz_Turi    6 non-null      object
#  6   Kanal         7 non-null      float64
# dtypes: float64(4), object(3)
# memory usage: 580.0+ bytes

# %%
# ustunlardagi nan qiymatlar soni
df.isnull().sum()
# Out:
# Savdo_Xodimi    0
# Ball            2
# Sotuv_soni      2
# Tashrif         2
# Shahar          3
# Mijoz_Turi      2
# Kanal           1
# dtype: int64

# %%
# barcha nanlarni 0 - standard qiymat bilan to'ldirish
df.fillna(0)
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         0.0      6.0          0      Katta    2.0
# 2            C   0.0        18.0      4.0     Buxoro          0    1.0
# 3            D  75.0        20.0      0.0  Samarqand      Katta    3.0
# 4            E  80.0         0.0      7.0          0     Kichik    2.0
# 5            F   0.0        22.0      5.0   Toshkent      Katta    0.0
# 6            G  95.0        25.0      0.0     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0          0          0    3.0

# %%
# ball ustunidagi nanlarni 11 bilan to'ldirish
df.fillna({'Ball':11})
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C  11.0        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F  11.0        22.0      5.0   Toshkent      Katta    NaN
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
# sotuv_soni ustunidagi nanlarni 5 va tashrif ustunini nanlarini 4 bilan to'ldirish
df.fillna({'Sotuv_soni':5, 'Tashrif':4})
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         5.0      6.0        NaN      Katta    2.0
# 2            C   NaN        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      4.0  Samarqand      Katta    3.0
# 4            E  80.0         5.0      7.0        NaN     Kichik    2.0
# 5            F   NaN        22.0      5.0   Toshkent      Katta    NaN
# 6            G  95.0        25.0      4.0     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
# ball ustunidagi nanlarni , shu ustun o'rtacha qiymati bn to'ldirish
ball_mean = np.mean(df['Ball']).round(1)
df.fillna({'Ball':ball_mean})
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C  84.7        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F  84.7        22.0      5.0   Toshkent      Katta    NaN
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
df
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C   NaN        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F   NaN        22.0      5.0   Toshkent      Katta    NaN
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
# ustunlardagi nan qiymatlarni o'zidan oldingi qiymat bn to'ldirish
df.ffill()
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0        15.0      6.0   Toshkent      Katta    2.0
# 2            C  92.0        18.0      4.0     Buxoro      Katta    1.0
# 3            D  75.0        20.0      4.0  Samarqand      Katta    3.0
# 4            E  80.0        20.0      7.0  Samarqand     Kichik    2.0
# 5            F  80.0        22.0      5.0   Toshkent      Katta    2.0
# 6            G  95.0        25.0      5.0     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0     Buxoro     Kichik    3.0

# %%
# yuqoridagini aksi , nanni o'zidan keyingi qiymat bilan to'ldirish
df.bfill()
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0        18.0      6.0     Buxoro      Katta    2.0
# 2            C  75.0        18.0      4.0     Buxoro      Katta    1.0
# 3            D  75.0        20.0      7.0  Samarqand      Katta    3.0
# 4            E  80.0        22.0      7.0   Toshkent     Kichik    2.0
# 5            F  95.0        22.0      5.0   Toshkent      Katta    1.0
# 6            G  95.0        25.0      6.0     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
df['Shahar'].value_counts()
# Out:
# Shahar
# Toshkent     2
# Buxoro       2
# Samarqand    1
# Name: count, dtype: int64

# %%
df[df['Shahar'] == 'Toshkent']
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif    Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0  Toshkent     Kichik    1.0
# 5            F   NaN        22.0      5.0  Toshkent      Katta    NaN

# %%
# toshkentning barcha nanlarini bir xil ma'lumot bilan to'ldirish
df[df['Shahar'] == 'Toshkent'] = df[df['Shahar'] == 'Toshkent'].ffill()

# %%
df
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C   NaN        18.0      4.0     Buxoro        NaN    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F  88.0        22.0      5.0   Toshkent      Katta    1.0
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
# Buxoro ma'lumotlariniyam bir xil qilib to'ldirish
df[df['Shahar'] == 'Buxoro'] = df[df['Shahar'] == 'Buxoro'].bfill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Savdo_Xodimi  8 non-null      object
#  1   Ball          8 non-null      float64
#  2   Sotuv_soni    6 non-null      float64
#  3   Tashrif       6 non-null      float64
#  4   Shahar        5 non-null      object
#  5   Mijoz_Turi    7 non-null      object
#  6   Kanal         8 non-null      float64
# dtypes: float64(4), object(3)
# memory usage: 580.0+ bytes

# %%
df2 = df.copy()
df2
# Out:
#   Savdo_Xodimi  Ball  Sotuv_soni  Tashrif     Shahar Mijoz_Turi  Kanal
# 0            A  88.0        15.0      5.0   Toshkent     Kichik    1.0
# 1            B  92.0         NaN      6.0        NaN      Katta    2.0
# 2            C  95.0        18.0      4.0     Buxoro     Kichik    1.0
# 3            D  75.0        20.0      NaN  Samarqand      Katta    3.0
# 4            E  80.0         NaN      7.0        NaN     Kichik    2.0
# 5            F  88.0        22.0      5.0   Toshkent      Katta    1.0
# 6            G  95.0        25.0      NaN     Buxoro     Kichik    1.0
# 7            H  78.0        14.0      6.0        NaN        NaN    3.0

# %%
df2.drop(['Savdo_Xodimi', 'Shahar', 'Mijoz_Turi'], axis='columns', inplace=True)

# %%
df2
# Out:
#    Ball  Sotuv_soni  Tashrif  Kanal
# 0  88.0        15.0      5.0    1.0
# 1  92.0         NaN      6.0    2.0
# 2  95.0        18.0      4.0    1.0
# 3  75.0        20.0      NaN    3.0
# 4  80.0         NaN      7.0    2.0
# 5  88.0        22.0      5.0    1.0
# 6  95.0        25.0      NaN    1.0
# 7  78.0        14.0      6.0    3.0

# %%
# barcha ustunlardagi nanlarni o'zining o'rta qiymati bilan to'ldirish
df2.fillna(df2.mean())
# Out:
#    Ball  Sotuv_soni  Tashrif  Kanal
# 0  88.0        15.0      5.0    1.0
# 1  92.0        19.0      6.0    2.0
# 2  95.0        18.0      4.0    1.0
# 3  75.0        20.0      5.5    3.0
# 4  80.0        19.0      7.0    2.0
# 5  88.0        22.0      5.0    1.0
# 6  95.0        25.0      5.5    1.0
# 7  78.0        14.0      6.0    3.0

# %% [markdown]
# *topshiriqlar*

# %%
df3 = pd.DataFrame({
    "age": [25, np.nan, 30, np.nan, 40],
    "salary": [500, 600, np.nan, 800, np.nan]
})
df3
# Out:
#     age  salary
# 0  25.0   500.0
# 1   NaN   600.0
# 2  30.0     NaN
# 3   NaN   800.0
# 4  40.0     NaN

# %%
# age ustunidagi NaN’larni o‘rtacha qiymat bilan to‘ldirish
df3['age'].fillna(df3['age'].mean().round(1))
# Out:
# 0    25.0
# 1    31.7
# 2    30.0
# 3    31.7
# 4    40.0
# Name: age, dtype: float64

# %%
# salary ustunidagi NaN’larni median bilan to‘ldirish
df3['salary'].fillna(df3['salary'].median())
# Out:
# 0    500.0
# 1    600.0
# 2    600.0
# 3    800.0
# 4    600.0
# Name: salary, dtype: float64

# %%
df4 = pd.DataFrame({
    "gender": ["male", "female", np.nan, "male", np.nan, "female"],
    "city": ["Toshkent", np.nan, "Samarqand", "Toshkent", np.nan, "Toshkent"]
})
df4
# Out:
#    gender       city
# 0    male   Toshkent
# 1  female        NaN
# 2     NaN  Samarqand
# 3    male   Toshkent
# 4     NaN        NaN
# 5  female   Toshkent

# %%
# gender va city ustunlaridagi NaN qiymatlarni eng ko‘p uchragan qiymat bilan to‘ldirish
df4['gender'].value_counts()
# Out:
# gender
# male      2
# female    2
# Name: count, dtype: int64

# %%
df4['city'].value_counts()
# Out:
# city
# Toshkent     3
# Samarqand    1
# Name: count, dtype: int64

# %%
df4['city'].fillna('Toshkent')
# Out:
# 0     Toshkent
# 1     Toshkent
# 2    Samarqand
# 3     Toshkent
# 4     Toshkent
# 5     Toshkent
# Name: city, dtype: object

# %%
df4['gender'].fillna('female')
# Out:
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# 5    female
# Name: gender, dtype: object

# %%
df5 = pd.DataFrame({
    "A": [1, np.nan, 3],
    "B": [np.nan, 5, 6],
    "C": [7, 8, np.nan]
})
df5
# Out:
#      A    B    C
# 0  1.0  NaN  7.0
# 1  NaN  5.0  8.0
# 2  3.0  6.0  NaN

# %%
# A-0, B-1, C-maksimal qiymat bilan to'ldirish
fill_df5 = {
    'A':0,
    'B':1,
    'C':df5['C'].max()
}
df5.fillna(fill_df5)
# Out:
#      A    B    C
# 0  1.0  1.0  7.0
# 1  0.0  5.0  8.0
# 2  3.0  6.0  8.0

# %%
ser1 = pd.Series([10, np.nan, np.nan, 40, np.nan, 60])
ser1
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# 3    40.0
# 4     NaN
# 5    60.0
# dtype: float64

# %%
# NaN’larni oldingi to‘liq qiymat bilan to‘ldirish
ser1.ffill()
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    40.0
# 4    40.0
# 5    60.0
# dtype: float64

# %%
ser2 = pd.Series([np.nan, 20, np.nan, np.nan, 50])
ser2
# Out:
# 0     NaN
# 1    20.0
# 2     NaN
# 3     NaN
# 4    50.0
# dtype: float64

# %%
# keyingi qiymatlar bilan to'ldirish
ser2.bfill()
# Out:
# 0    20.0
# 1    20.0
# 2    50.0
# 3    50.0
# 4    50.0
# dtype: float64
