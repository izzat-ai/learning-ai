# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/scikit-learn/ColumnsTransformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ushbu sahifada bir vaqtning o'zida DF ning turli ustunlariga transformatorlarni qo'llashni amaliyot qilamiz - ColumnTransformer**

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.DataFrame({
    "age": [20, 25, 30, 35, 40, 45],
    "salary": [2000, 3000, 4000, 5000, 6000, 7000],
    "city": [
        "Tashkent",
        "Samarkand",
        "Bukhara",
        "Tashkent",
        "Samarkand",
        "Bukhara"
    ],
    "gender": [
        "Male",
        "Female",
        "Male",
        "Female",
        "Male",
        "Female"
    ]
})
df
# Out:
#    age  salary       city  gender
# 0   20    2000   Tashkent    Male
# 1   25    3000  Samarkand  Female
# 2   30    4000    Bukhara    Male
# 3   35    5000   Tashkent  Female
# 4   40    6000  Samarkand    Male
# 5   45    7000    Bukhara  Female

# %%
X = df[['age', 'salary', 'city', 'gender']]

# train va testlarga bo'lish
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)

print("train shape:", X_train.shape)
print("test shape:", X_test.shape)
# Out:
# train shape: (4, 4)
# test shape: (2, 4)

# %%
# sonli va matnli ustunlar nomlarini olish
num_cols = X_train.select_dtypes(include=np.number).columns.tolist()
cat_cols = X_train.select_dtypes(exclude=np.number).columns.tolist()

num_cols
# Out:
# ['age', 'salary']

# %%
cat_cols
# Out:
# ['city', 'gender']

# %%
# kerakli paketlarni chaqirish
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

num_pipe = Pipeline([
    ('scaler', StandardScaler())
])

full_pipeline = ColumnTransformer([
    ('num', num_pipe, num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols)
])

# %%
X_train_prepared = full_pipeline.fit_transform(X_train)
X_train_prepared
# Out:
# array([[ 1.34164079,  1.34164079,  1.        ,  0.        ,  0.        ,
#          1.        ,  0.        ],
#        [-1.34164079, -1.34164079,  1.        ,  0.        ,  0.        ,
#          0.        ,  1.        ],
#        [ 0.4472136 ,  0.4472136 ,  0.        ,  1.        ,  0.        ,
#          0.        ,  1.        ],
#        [-0.4472136 , -0.4472136 ,  0.        ,  0.        ,  1.        ,
#          1.        ,  0.        ]])

# %%
X_test_prepared = full_pipeline.transform(X_test)
X_test_prepared
# Out:
# array([[-3.13049517, -3.13049517,  0.        ,  0.        ,  1.        ,
#          0.        ,  1.        ],
#        [-2.23606798, -2.23606798,  0.        ,  1.        ,  0.        ,
#          1.        ,  0.        ]])
