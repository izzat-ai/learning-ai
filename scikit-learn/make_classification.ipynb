# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/scikit-learn/make_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ushbu sahifada sklearn orqali klassifikatsiya va regressiya modellarini yaratish uchun sun'iy dataset yaratishni o'rganamiz**

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
# klassifikatsiya uchun sun'iy dataset yaratish
from sklearn.datasets import make_classification

X, y = make_classification()
