# %% [markdown]
# <a href="https://colab.research.google.com/github/izzat-ai/learning-ai/blob/main/numpy/practice_all02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# Create a numpy array from this list and display it on the screen
data = [10, 20, 30, 40, 50]
arr1 = np.array(data)
arr1
# Out:
# array([10, 20, 30, 40, 50])
